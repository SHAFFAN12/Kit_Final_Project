# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/CourseraDataset.csv', encoding='latin')
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     NaN
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  CrÃ©er du contenu pour les rÃ©seaux sociaux av...     NaN
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
data.head(5)
# Out:
#                                         Course Title  Rating           Level  \
# 0                                  Fashion as Design     4.8  Beginner level
# 1                             Modern American Poetry     4.4  Beginner level
# 2                          Pixel Art for Video Games     4.5  Beginner level
# 3  DistribuciÃ³n digital de la mÃºsica independiente     NaN  Beginner level
# 4  The Blues: Understanding and Performing an Ame...     4.8  Beginner level
#
#                        Duration           Schedule         Review  \
# 0      20 hours (approximately)  Flexible schedule  2,813 reviews
# 1  Approx. 34 hours to complete  Flexible schedule    100 reviews
# 2       9 hours (approximately)  Flexible schedule    227 reviews
# 3   Approx. 8 hours to complete  Flexible schedule            NaN
# 4  Approx. 11 hours to complete  Flexible schedule    582 reviews
#
#                                  What you will learn  \
# ...

# %%
data.shape
# Out:
# (9595, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9595 entries, 0 to 9594
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Course Title         9595 non-null   object
#  1   Rating               8156 non-null   float64
#  2   Level                8330 non-null   object
#  3   Duration             9333 non-null   object
#  4   Schedule             8912 non-null   object
#  5   Review               8152 non-null   object
#  6   What you will learn  4984 non-null   object
#  7   Skill gain           9595 non-null   object
#  8   Modules              9595 non-null   object
#  9   Instructor           9595 non-null   object
#  10  Offered By           9595 non-null   object
#  11  Keyword              9595 non-null   object
#  12  Course Url           9595 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 974.6+ KB

# %%
data.describe()
# Out:
#             Rating
# count  8156.000000
# mean      4.651533
# std       0.240674
# min       1.500000
# 25%       4.600000
# 50%       4.700000
# 75%       4.800000
# max       5.000000

# %%
data.duplicated().sum()
# Out:
# 900

# %%
data.isnull().sum()
# Out:
# Course Title              0
# Rating                 1439
# Level                  1265
# Duration                262
# Schedule                683
# Review                 1443
# What you will learn    4611
# Skill gain                0
# Modules                   0
# Instructor                0
# Offered By                0
# Keyword                   0
# Course Url                0
# dtype: int64

# %%
data = data.drop_duplicates()

# %% [markdown]
# # **Duration Column Cleaning**

# %%
data['Duration'] = data.Duration.str.extract('(\d+)').astype('Int64')
# Out:
# <ipython-input-474-42698082d65b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Duration'] = data.Duration.str.extract('(\d+)').astype('Int64')

# %%
data = data.rename(columns = ({'Duration':"Duration to complete in hours (Approx.)"}))
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     NaN
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     NaN
# 8692          CÃ³mo combinar y analizar datos complejos     NaN
# 8693  Architecting with Google Kubernetes Engine: Wo...     NaN
# 8694                 Visualizing static networks with R     NaN
#
#                    Level  Duration to complete in hours (Approx.)  \
# 0         Beginner level                                       20
# ...

# %%
data['Duration to complete in hours (Approx.)'] = data['Duration to complete in hours (Approx.)'].replace(np.nan,0)
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     NaN
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     NaN
# 8692          CÃ³mo combinar y analizar datos complejos     NaN
# 8693  Architecting with Google Kubernetes Engine: Wo...     NaN
# 8694                 Visualizing static networks with R     NaN
#
#                    Level  Duration to complete in hours (Approx.)  \
# 0         Beginner level                                       20
# ...

# %% [markdown]
# # **Review Cleaning**

# %%
data['Review'] = data['Review'].str.replace(',','')
data['Review'] = data['Review'].str.replace('reviews','')
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     NaN
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     NaN
# 8692          CÃ³mo combinar y analizar datos complejos     NaN
# 8693  Architecting with Google Kubernetes Engine: Wo...     NaN
# 8694                 Visualizing static networks with R     NaN
#
#                    Level  Duration to complete in hours (Approx.)  \
# 0         Beginner level                                       20
# ...

# %%
data['Review'] = data['Review'].replace(np.nan,0)
data['Review'] = data['Review'].astype('int64')
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     NaN
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     NaN
# 8692          CÃ³mo combinar y analizar datos complejos     NaN
# 8693  Architecting with Google Kubernetes Engine: Wo...     NaN
# 8694                 Visualizing static networks with R     NaN
#
#                    Level  Duration to complete in hours (Approx.)  \
# 0         Beginner level                                       20
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8695 entries, 0 to 8694
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Course Title                             8695 non-null   object
#  1   Rating                                   7346 non-null   float64
#  2   Level                                    7589 non-null   object
#  3   Duration to complete in hours (Approx.)  8695 non-null   Int64
#  4   Schedule                                 8054 non-null   object
#  5   Review                                   8695 non-null   int64
#  6   What you will learn                      4585 non-null   object
#  7   Skill gain                               8695 non-null   object
#  8   Modules                                  8695 non-null   object
#  9   Instructor                               8695 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Course Title                                  0
# Rating                                     1349
# Level                                      1106
# Duration to complete in hours (Approx.)       0
# Schedule                                    641
# Review                                        0
# What you will learn                        4110
# Skill gain                                    0
# Modules                                       0
# Instructor                                    0
# Offered By                                    0
# Keyword                                       0
# Course Url                                    0
# dtype: int64

# %% [markdown]
# # ***Rating Column Cleaning***

# %%
data['Rating'] = data['Rating'].fillna(0.0)
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#                    Level  Duration to complete in hours (Approx.)  \
# 0         Beginner level                                       20
# ...

# %% [markdown]
# # ***Level Column Cleaning***

# %%
data['Level'] = data['Level'].replace(np.nan,"unknown")
data.head(13)
# Out:
#                                          Course Title  Rating  \
# 0                                   Fashion as Design     4.8
# 1                              Modern American Poetry     4.4
# 2                           Pixel Art for Video Games     4.5
# 3   DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4   The Blues: Understanding and Performing an Ame...     4.8
# 5                        So You Think You Know Tango?     4.6
# 6                          The Politics of Skepticism     4.5
# 7   Ð¡ÑÐ°Ð½Ð¾Ð²Ð»ÐµÐ½Ð½Ñ ÑÑÑÐ°ÑÐ½Ð¾Ñ Ð£ÐºÑ...     0.0
# 8          Exploring Beethoven's Piano Sonatas Part 4     4.9
# 9                            æè®ºï¼æç»´çé­æ¹     4.8
# 10                  ææï¼ååªè¾å¸ä¸æ ·ææ     4.8
# 11           In the Studio: Postwar Abstract Painting     4.9
# 12                              Philosophy of Science     4.7
#
#                  Level  Duration to complete in hours (Approx.)  \
# ...

# %%
data['Level'] = data['Level'].str.replace("level","")
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %% [markdown]
# # ***Schedule Column Cleaning***

# %%
data['Schedule'] = data['Schedule'].replace(np.nan,"Hands-on learning")
data['Schedule'] = data['Schedule'].str.replace("schedule","")

# %%
data.head(17)
# Out:
#                                          Course Title  Rating          Level  \
# 0                                   Fashion as Design     4.8      Beginner
# 1                              Modern American Poetry     4.4      Beginner
# 2                           Pixel Art for Video Games     4.5      Beginner
# 3   DistribuciÃ³n digital de la mÃºsica independiente     0.0      Beginner
# 4   The Blues: Understanding and Performing an Ame...     4.8      Beginner
# 5                        So You Think You Know Tango?     4.6      Beginner
# 6                          The Politics of Skepticism     4.5  Intermediate
# 7   Ð¡ÑÐ°Ð½Ð¾Ð²Ð»ÐµÐ½Ð½Ñ ÑÑÑÐ°ÑÐ½Ð¾Ñ Ð£ÐºÑ...     0.0      Beginner
# 8          Exploring Beethoven's Piano Sonatas Part 4     4.9  Intermediate
# 9                            æè®ºï¼æç»´çé­æ¹     4.8      Beginner
# 10                  ææï¼ååªè¾å¸ä¸æ ·ææ     4.8        unknown
# ...

# %% [markdown]
# # **"What you will learn"  Column Cleaning**

# %%
data = data.rename(columns = ({'What you will learn':"Description"}))
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %%
data['Description'] = data['Description'].replace(np.nan,"unknown")
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %% [markdown]
# # ***Skill-gain Column Cleaning***

# %%
data = data.rename(columns = ({'Skill gain':"Skill_gain"}))
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %%
data['Skill_gain'] = data['Skill_gain'].replace("[]", "Not-Specified")
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %%
data['Skill_gain'] = data['Skill_gain'].str.strip().str.replace(r"[\[\]\']", '', regex = True)
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %% [markdown]
# # ***Modules Column Cleaning***

# %%
data['Modules'] = data['Modules'].str.strip().str.replace(r"[\[\]\']", '', regex = True)
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %%
# comma_counter = 1
# for i in range(len(data['Modules'])):
#   if data['Modules'].iloc[i].count(",") > 0:
#     # Split the data by comma and store it in a new column
#     data[f"Column {comma_counter}"] = data['Modules'].iloc[i].split(",",)[0]
#     comma_counter += 1

# data[['column 1','column 2']] = data['Modules'].str.split(',',expand=True)


# data[''] = data['Modules'].str.split(',', expand=True)
# data.head()

data[['Module-1','Module-2','Module-3','Module-4','Module-5','Module-6','Module-7','Module-8','Module-9','Module-10','Module-11','Module-12','Module-13','Module-14','Module-15','Module-16','Module-17','Module-18','Module-19','Module-20','Module-21','Module-22','Module-23','Module-24','Module-25','Module-26','Module-27','Module-28','Module-29','Module-30']] = data['Modules'].str.split(',',29 ,expand=True)
# Out:
# <ipython-input-492-847f5d03ad67>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data[['Module-1','Module-2','Module-3','Module-4','Module-5','Module-6','Module-7','Module-8','Module-9','Module-10','Module-11','Module-12','Module-13','Module-14','Module-15','Module-16','Module-17','Module-18','Module-19','Module-20','Module-21','Module-22','Module-23','Module-24','Module-25','Module-26','Module-27','Module-28','Module-29','Module-30']] = data['Modules'].str.split(',',29 ,expand=True)

# %%
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %% [markdown]
# # ***INSTRUCTOR Column Cleaning***

# %%
data = data.rename(columns = ({'Instructor':"Instructors"}))
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %%
data['Instructors'] = data['Instructors'].str.strip().str.replace(r"[\[\]\']", '', regex = True)
data['Instructors'] = data['Instructors'].replace('',"unknown")
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3     DistribuciÃ³n digital de la mÃºsica independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 1         Beginner                                        34
# ...

# %%
data_frames = []

for sublist in split_data:
    df = pd.DataFrame([sublist], columns=[f"instructor_{i+1}" for i in range(len(sublist))])
    data_frames.append(df)

final_df = pd.concat(data_frames)

final_df
data = data.join(final_df)

# %%
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 0         Beginner                                        20
# ...

# %% [markdown]
# # ***Offered By Column Cleaning***

# %%
data['Offered By'] = data['Offered By'].str.strip().str.replace(r"[\[\]\']", '', regex = True)
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 0         Beginner                                        20
# ...

# %%
data['Offered By'] = data['Offered By'].replace('',"unknown")
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 0         Beginner                                        20
# ...

# %%
data.drop_duplicates()
data
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# 0                                     Fashion as Design     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692          CÃ³mo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#               Level  Duration to complete in hours (Approx.)  \
# 0         Beginner                                        20
# 0         Beginner                                        20
# ...

# %%
data.to_excel('Clean_data_set.xlsx',index=False)

# %%
plt.figure(figsize=(10,5))
custom_colors = ["#3974A2", "#E1812C", "#44923B", "#C03D3E"]

sns.barplot(data, x='Level', y='Duration to complete in hours (Approx.)', palette=custom_colors)
plt.show()
# Out:
# <ipython-input-502-31a8af6418d5>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data, x='Level', y='Duration to complete in hours (Approx.)', palette=custom_colors)

# %%
plt.figure(figsize=(15, 7))
sns.barplot(data, x='Rating', y='Duration to complete in hours (Approx.)')
# Out:
# <Axes: xlabel='Rating', ylabel='Duration to complete in hours (Approx.)'>

# %%
plt.figure(figsize=(10, 7))

counts = data.Keyword.value_counts()[::-1]
plt.figure(figsize=(12, 8))
bars = plt.barh(counts.index, counts.values, color=sns.color_palette())

# Formatting the number with commas and displaying it with a small distance from the bars
for bar in bars:
    width = bar.get_width()
    label_x_pos = width + 20  # Adding a small distance from the end of the bar
    plt.text(label_x_pos, bar.get_y() + bar.get_height()/2, f"{width:,.0f}", va='center', color='red')

plt.xlabel('Frequency')
plt.ylabel('Keyword')
plt.title('Keyword Frequency', color='red', fontweight='bold')

# Display both horizontal and vertical grid lines
plt.grid(axis='both', linestyle='-', alpha=0.3)

# Change the x-axis limit to 400,000
plt.xlim(0, 1050)
plt.show()

# %%
plt.bar(data['Schedule'], data['Duration to complete in hours (Approx.)'], color='lightpink', edgecolor='black')
plt.show()

# %%
plt.bar(data['Schedule'],data['Level'], color='darkblue', edgecolor='black')
plt.show()

# %%
plt.scatter(data['Review'],data['Level'], color ='black')
plt.show()
